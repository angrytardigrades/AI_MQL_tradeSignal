# %%
import numpy as np
import pandas as pd
import sklearn as skt

# %%
data = pd.read_csv("report_final.csv")
df = pd.DataFrame(data)

# %%
data["ccpi"]=data["ccpi"].round(decimals=2)
data["ma"]=data["ma"].round(decimals=5)
data["findex"]=data["findex"].round(decimals=5)
data["rvi"]=data["rvi"].round(decimals=5)
data["rsi"]=data["rsi"].round(decimals=5)
data_r=data.drop(["datetime","tvol","findex","rvi","rsi","spr"],axis=1)
data_r=data_r.drop(data.tail(100).index,axis=0)

# %%
data_r
# Out:
#           open     high      low    close    ccpi       ma  signal
# 0      1.09545  1.09898  1.09335  1.09698   27.54  1.09421       0
# 1      1.09728  1.09840  1.09174  1.09558   45.24  1.09334       1
# 2      1.09269  1.09830  1.09202  1.09723   34.24  1.09282       0
# 3      1.09886  1.09998  1.09093  1.09287  147.40  1.09217       0
# 4      1.10462  1.10759  1.09724  1.09946  215.33  1.09102       0
# ...        ...      ...      ...      ...     ...      ...     ...
# 11114  1.09030  1.09030  1.09020  1.09030   58.67  1.08826       0
# 11115  1.09220  1.09250  1.09180  1.09200   82.54  1.08793       0
# 11116  1.09300  1.09340  1.09290  1.09300   49.36  1.08682       0
# 11117  1.09020  1.09050  1.09020  1.09030   76.73  1.08568       0
# 11118  1.09200  1.09210  1.09200  1.09200  -47.54  1.08426       0
#
# [11119 rows x 7 columns]

# %%
data_r.to_csv("data_r.csv")

# %%
X = data_r.drop("signal",axis=1)
y= data_r["signal"]
X
# Out:
#           open     high      low    close    ccpi       ma
# 0      1.09545  1.09898  1.09335  1.09698   27.54  1.09421
# 1      1.09728  1.09840  1.09174  1.09558   45.24  1.09334
# 2      1.09269  1.09830  1.09202  1.09723   34.24  1.09282
# 3      1.09886  1.09998  1.09093  1.09287  147.40  1.09217
# 4      1.10462  1.10759  1.09724  1.09946  215.33  1.09102
# ...        ...      ...      ...      ...     ...      ...
# 11114  1.09030  1.09030  1.09020  1.09030   58.67  1.08826
# 11115  1.09220  1.09250  1.09180  1.09200   82.54  1.08793
# 11116  1.09300  1.09340  1.09290  1.09300   49.36  1.08682
# 11117  1.09020  1.09050  1.09020  1.09030   76.73  1.08568
# 11118  1.09200  1.09210  1.09200  1.09200  -47.54  1.08426
#
# [11119 rows x 6 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
clf.score(X_test,y_test)
# Out:
# 0.6191546762589928
